# %%
import pandas as pd

# %%
df =pd.read_csv('Pokemon.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49  \
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49  \
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df[["Name",'Speed']]
# Out:
#                       Name  Speed
# 0                Bulbasaur     45
# 1                  Ivysaur     60
# 2                 Venusaur     80
# 3    VenusaurMega Venusaur     80
# 4               Charmander     65
# ..                     ...    ...
# 795                Diancie     50
# 796    DiancieMega Diancie    110
# 797    HoopaHoopa Confined     70
# 798     HoopaHoopa Unbound     80
# 799              Volcanion     70
#
# [800 rows x 2 columns]

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
df['Speed'].dtypes
# Out:
# dtype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.select_dtypes(include='int') # select data types
# Out:
#        #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      1    318  45      49       49       65       65     45           1
# 1      2    405  60      62       63       80       80     60           1
# 2      3    525  80      82       83      100      100     80           1
# 3      3    625  80     100      123      122      120     80           1
# 4      4    309  39      52       43       60       50     65           1
# ..   ...    ...  ..     ...      ...      ...      ...    ...         ...
# 795  719    600  50     100      150      100      150     50           6
# 796  719    700  50     160      110      160      110    110           6
# 797  720    600  80     110       60      150      130     70           6
# 798  720    680  80     160       60      170      130     80           6
# 799  721    600  80     110      120      130       90     70           6
#
# [800 rows x 9 columns]

# %%
df.select_dtypes(include='object')
# Out:
#                       Name   Type 1  Type 2
# 0                Bulbasaur    Grass  Poison
# 1                  Ivysaur    Grass  Poison
# 2                 Venusaur    Grass  Poison
# 3    VenusaurMega Venusaur    Grass  Poison
# 4               Charmander     Fire     NaN
# ..                     ...      ...     ...
# 795                Diancie     Rock   Fairy
# 796    DiancieMega Diancie     Rock   Fairy
# 797    HoopaHoopa Confined  Psychic   Ghost
# 798     HoopaHoopa Unbound  Psychic    Dark
# 799              Volcanion     Fire   Water
#
# [800 rows x 3 columns]

# %%
df.select_dtypes(include='bool')
# Out:
#      Legendary
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 795       True
# 796       True
# 797       True
# 798       True
# 799       True
#
# [800 rows x 1 columns]

# %%
df.select_dtypes(include=['object',bool])
# Out:
#                       Name   Type 1  Type 2  Legendary
# 0                Bulbasaur    Grass  Poison      False
# 1                  Ivysaur    Grass  Poison      False
# 2                 Venusaur    Grass  Poison      False
# 3    VenusaurMega Venusaur    Grass  Poison      False
# 4               Charmander     Fire     NaN      False
# ..                     ...      ...     ...        ...
# 795                Diancie     Rock   Fairy       True
# 796    DiancieMega Diancie     Rock   Fairy       True
# 797    HoopaHoopa Confined  Psychic   Ghost       True
# 798     HoopaHoopa Unbound  Psychic    Dark       True
# 799              Volcanion     Fire   Water       True
#
# [800 rows x 4 columns]

# %%
#statistical information
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000  \
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df['HP'].describe()
# Out:
# count    800.000000
# mean      69.258750
# std       25.534669
# min        1.000000
# 25%       50.000000
# 50%       65.000000
# 75%       80.000000
# max      255.000000
# Name: HP, dtype: float64

# %%
df[['HP','Defense']].describe()
# Out:
#                HP     Defense
# count  800.000000  800.000000
# mean    69.258750   73.842500
# std     25.534669   31.183501
# min      1.000000    5.000000
# 25%     50.000000   50.000000
# 50%     65.000000   70.000000
# 75%     80.000000   90.000000
# max    255.000000  230.000000

# %%
#slicing,location,index of location
df # df=df.iloc[:,:]
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49  \
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
#df[row,col]
#df.iloc[:,:] #[start:end]
df.iloc[100:200]
# Out:
#        #                   Name    Type 1  Type 2  Total   HP  Attack
# 100   93                Haunter     Ghost  Poison    405   45      50  \
# 101   94                 Gengar     Ghost  Poison    500   60      65
# 102   94      GengarMega Gengar     Ghost  Poison    600   60      65
# 103   95                   Onix      Rock  Ground    385   35      45
# 104   96                Drowzee   Psychic     NaN    328   60      48
# ..   ...                    ...       ...     ...    ...  ...     ...
# 195  181               Ampharos  Electric     NaN    510   90      75
# 196  181  AmpharosMega Ampharos  Electric  Dragon    610   90      95
# 197  182              Bellossom     Grass     NaN    490   75      80
# 198  183                 Marill     Water   Fairy    250   70      20
# 199  184              Azumarill     Water   Fairy    420  100      50
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 100       45      115       55     95           1      False
# ...

# %%
df.iloc[100:200:2] #[start:end:step] increasing order
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack
# 100   93                    Haunter     Ghost    Poison    405   45      50  \
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 104   96                    Drowzee   Psychic       NaN    328   60      48
# 106   98                     Krabby     Water       NaN    325   30     105
# 108  100                    Voltorb  Electric       NaN    330   40      30
# 110  102                  Exeggcute     Grass   Psychic    325   60      40
# 112  104                     Cubone    Ground       NaN    320   50      50
# 114  106                  Hitmonlee  Fighting       NaN    455   50     120
# 116  108                  Lickitung    Normal       NaN    385   90      55
# 118  110                    Weezing    Poison       NaN    490   65      90
# 120  112                     Rhydon    Ground      Rock    485  105     130
# ...

# %%
df.iloc[100:30:-3] #[start:end:step] decreasing order
# Out:
#       #        Name    Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk
# 100  93     Haunter     Ghost    Poison    405  45      50       45      115  \
# 97   90    Shellder     Water       NaN    305  30      65      100       45
# 94   87     Dewgong     Water       Ice    475  90      70       80       70
# 91   84       Doduo    Normal    Flying    310  35      85       45       35
# 88   81   Magnemite  Electric     Steel    325  25      35       70       95
# 85   79    Slowpoke     Water   Psychic    315  90      65       65       40
# 82   76       Golem      Rock    Ground    495  80     120      130       55
# 79   73  Tentacruel     Water    Poison    515  80      70       65       80
# 76   70  Weepinbell     Grass    Poison    390  65      90       50       85
# 73   67     Machoke  Fighting       NaN    405  80     100       70       50
# 70   65    Alakazam   Psychic       NaN    500  55      50       45      135
# ...

# %%
df.iloc[100:30:-3][['Name','HP']]
# Out:
#            Name  HP
# 100     Haunter  45
# 97     Shellder  30
# 94      Dewgong  90
# 91        Doduo  35
# 88    Magnemite  25
# 85     Slowpoke  90
# 82        Golem  80
# 79   Tentacruel  80
# 76   Weepinbell  65
# 73      Machoke  80
# 70     Alakazam  55
# 67    Poliwrath  90
# 64     Arcanine  90
# 61       Mankey  40
# 58      Persian  65
# 55      Diglett  10
# 52     Parasect  60
# 49        Gloom  60
# 46        Zubat  40
# 43    Ninetales  73
# 40     Clefairy  70
# 37     Nidoran♂  46
# 34     Nidoran♀  55
# 31       Raichu  60

# %%
df[700:400:-3][['Sp. Atk','Legendary']]
# Out:
#      Sp. Atk  Legendary
# 700       72       True
# 697       50      False
# 694       45      False
# 691       55      False
# 688       37      False
# ..       ...        ...
# 415      100       True
# 412       95      False
# 409      120      False
# 406       40      False
# 403      114      False
#
# [100 rows x 2 columns]

# %%
df[100:200:1]['HP'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 100     45
# 101     60
# 102     60
# 103     35
# 104     60
#       ...
# 195     90
# 196     90
# 197     75
# 198     70
# 199    100
# Name: HP, Length: 100, dtype: int64>

# %%
df[100:200:1]['HP'].describe()
# Out:
# count    100.00000
# mean      70.09000
# std       31.52331
# min       20.00000
# 25%       50.00000
# 50%       65.00000
# 75%       86.25000
# max      250.00000
# Name: HP, dtype: float64

# %%
df[100:200:1]['HP'].std()
# Out:
# 31.523310278412875

# %%
df[100:200:1]['HP'].std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of 100     45
# 101     60
# 102     60
# 103     35
# 104     60
#       ...
# 195     90
# 196     90
# 197     75
# 198     70
# 199    100
# Name: HP, Length: 100, dtype: int64>

# %%
#slicing- index,condition (values)
#location,
#index of location

#condition -. loc/iloc
df.iloc[:,df.columns=='HP'] # all row @ only HP column (with iloc row cannot be condition )
# Out:
#      HP
# 0    45
# 1    60
# 2    80
# 3    80
# 4    39
# ..   ..
# 795  50
# 796  50
# 797  80
# 798  80
# 799  80
#
# [800 rows x 1 columns]

# %%
df.iloc[:,df.columns!='HP'] # all row @ without HP column
# Out:
#        #                   Name   Type 1  Type 2  Total  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison    318      49       49  \
# 1      2                Ivysaur    Grass  Poison    405      62       63
# 2      3               Venusaur    Grass  Poison    525      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625     100      123
# 4      4             Charmander     Fire     NaN    309      52       43
# ..   ...                    ...      ...     ...    ...     ...      ...
# 795  719                Diancie     Rock   Fairy    600     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680     160       60
# 799  721              Volcanion     Fire   Water    600     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['HP']>70,df.columns=='Speed'] #iloc(row without condition) -loc(row with condition)
# Out:
#      Speed
# 2       80
# 3       80
# 6      100
# 7      100
# 8      100
# ..     ...
# 793     99
# 794     95
# 797     70
# 798     80
# 799     70
#
# [321 rows x 1 columns]

# %%
#logical operator -and (&) , or (|)
cond1=df.columns=='Speed'
cond2=df.columns=='HP'
df.loc[df['HP']>70,(cond1|cond2)]
# Out:
#       HP  Speed
# 2     80     80
# 3     80     80
# 6     78    100
# 7     78    100
# 8     78    100
# ..   ...    ...
# 793  126     99
# 794  108     95
# 797   80     70
# 798   80     80
# 799   80     70
#
# [321 rows x 2 columns]

# %%
df['Speed']>100

df.loc[df['HP']>70,(df.columns=='Speed'|df.columns=='HP')]
